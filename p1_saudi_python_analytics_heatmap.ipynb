# %%
import folium
from folium.plugins import HeatMap

# Heat map based on descriptive table from the SQL Workbench Database

#import mysql.connector
#mydb = mysql.connector.connect(
#host="localhost",
#user="username",
#password="yourpassword"
#)
#print (db)


# Instead, we will be using dump file to quickly test the data.

# *********************************** --
# ** Project 1 Data Engineering 23 ** --
# **        AVERAGE AMOUNT         ** --
# *********************************** --

data = [
    {"City": "Riyadh", "AVG": 79218.31, "latitude": 24.6333, "longitude": 46.7167},
    {"City": "Jeddah", "AVG": 71431.7, "latitude": 21.5433, "longitude": 39.1728},
    {"City": "Makkah", "AVG": 62283.51, "latitude": 21.4225, "longitude": 39.8233},
    {"City": "Madinah", "AVG": 61852.04, "latitude": 24.47, "longitude": 39.61},
    {"City": "Dammam", "AVG": 86106.6, "latitude": 26.4333, "longitude": 50.1},
    {"City": "Hafr Al Batin", "AVG": 57830.59, "latitude": 28.4342, "longitude": 45.9636},
    {"City": "Taif", "AVG": 62192.53, "latitude": 21.2751, "longitude": 40.4062},
    {"City": "Tabuk", "AVG": 59237.78, "latitude": 28.3972, "longitude": 36.5789},
    {"City": "Buraidah", "AVG": 63794.22, "latitude": 26.3333, "longitude": 43.9667},
    {"City": "Hail", "AVG": 57694.71, "latitude": 27.5167, "longitude": 41.6833},
    {"City": "Al-Qunfudhah", "AVG": 56187.81, "latitude": 19.1264, "longitude": 41.0789},
    {"City": "Yanbu", "AVG": 60259.83, "latitude": 24.0883, "longitude": 38.0582},
    {"City": "Qurayyat", "AVG": 56481.24, "latitude": 31.3167, "longitude": 37.3667},
    {"City": "Jazan", "AVG": 56965.86, "latitude": 16.8892, "longitude": 42.5611},
    {"City": "Khamis Mushait", "AVG": 65372.99, "latitude": 18.3, "longitude": 42.7333},
    {"City": "Najran", "AVG": 63529.69, "latitude": 17.4917, "longitude": 44.1322},
    {"City": "Arar", "AVG": 80926.19, "latitude": 30.9833, "longitude": 41.0167},
    {"City": "Al Baha", "AVG": 66285.87, "latitude": 20.0125, "longitude": 41.4653},
    {"City": "Al-Ahsa", "AVG": 61375.87, "latitude": 25.285579, "longitude": 49.486481},
    {"City": "Wadi Al-Dawasir", "AVG": 60791.56, "latitude": 20.559454, "longitude": 44.865658},
    {"City": "Majmaah", "AVG": 58553.52, "latitude": 25.896651, "longitude": 45.355737},
    {"City": "Dawadmi", "AVG": 58591.97, "latitude": 24.507143, "longitude": 44.408798},
    {"City": "Al-Jouf", "AVG": 58978.62, "latitude": 29.953894, "longitude": 40.197044},
    {"City": "Bisha", "AVG": 64403.94, "latitude": 20.00054, "longitude": 42.6052},
]

# Create a folium map centered around the first data point
m = folium.Map(location=[data[0]["latitude"], data[0]["longitude"]], zoom_start=6)

# Create a HeatMap layer
heat_data = [(point["latitude"], point["longitude"], point["AVG"]) for point in data]
HeatMap(heat_data).add_to(m)

# Display the map in the notebook
m

##### QUICK ANALYSIS #####
# We can see that higher average value of loans is around larger cities and ports.
# The loans were mostly distributed in Jeddah - Riyadh - Dammam corridor. 
# This makes sense as this is where all the infrastructure is located including railway and airports.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# *********************************** --
# ** Project 1 Data Engineering 23 ** --
# **        TOTAL COUNT         ** --
# *********************************** --

# Data provided
data = [
    {"City": "Riyadh", "Count": 11163, "latitude": 24.6333, "longitude": 46.7167},
    {"City": "Jeddah", "Count": 3556, "latitude": 21.5433, "longitude": 39.1728},
    {"City": "Makkah", "Count": 2892, "latitude": 21.4225, "longitude": 39.8233},
    {"City": "Madinah", "Count": 2821, "latitude": 24.47, "longitude": 39.61},
    {"City": "Dammam", "Count": 1707, "latitude": 26.4333, "longitude": 50.1},
    {"City": "Hafr Al Batin", "Count": 850, "latitude": 28.4342, "longitude": 45.9636},
    {"City": "Taif", "Count": 2919, "latitude": 21.2751, "longitude": 40.4062},
    {"City": "Tabuk", "Count": 2551, "latitude": 28.3972, "longitude": 36.5789},
    {"City": "Buraidah", "Count": 1820, "latitude": 26.3333, "longitude": 43.9667},
    {"City": "Hail", "Count": 1147, "latitude": 27.5167, "longitude": 41.6833},
    {"City": "Al-Qunfudhah", "Count": 731, "latitude": 19.1264, "longitude": 41.0789},
    {"City": "Yanbu", "Count": 2019, "latitude": 24.0883, "longitude": 38.0582},
    {"City": "Qurayyat", "Count": 773, "latitude": 31.3167, "longitude": 37.3667},
    {"City": "Jazan", "Count": 3427, "latitude": 16.8892, "longitude": 42.5611},
    {"City": "Khamis Mushait", "Count": 3490, "latitude": 18.3, "longitude": 42.7333},
    {"City": "Najran", "Count": 1090, "latitude": 17.4917, "longitude": 44.1322},
    {"City": "Arar", "Count": 840, "latitude": 30.9833, "longitude": 41.0167},
    {"City": "Al Baha", "Count": 1019, "latitude": 20.0125, "longitude": 41.4653},
    {"City": "Al-Ahsa", "Count": 1309, "latitude": 25.285579, "longitude": 49.486481},
    {"City": "Wadi Al-Dawasir", "Count": 403, "latitude": 20.559454, "longitude": 44.865658},
    {"City": "Majmaah", "Count": 383, "latitude": 25.896651, "longitude": 45.355737},
    {"City": "Dawadmi", "Count": 2490, "latitude": 24.507143, "longitude": 44.408798},
    {"City": "Al-Jouf", "Count": 842, "latitude": 29.953894, "longitude": 40.197044},
    {"City": "Bisha", "Count": 784, "latitude": 20.00054, "longitude": 42.6052},
]

# Create a folium map centered around the first data point
m2 = folium.Map(location=[data[0]["latitude"], data[0]["longitude"]], zoom_start=6)

# Create a HeatMap layer
heat_data = [(point["latitude"], point["longitude"], point["Count"]) for point in data]
HeatMap(heat_data).add_to(m2)

# Display the map in the notebook
m2


##### QUICK ANALYSIS #####
# We can see that vast majority of the loans were distributed in the capital - Riyadh.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
